# %% [markdown]
# # Exercise: Visualizing Data

# %% [markdown]
# Answer the following questions about `tips.csv`, which contains data from one waiter who recorded information about each tip he received over a period of a few months working in one restaurant. Include your final code below. When you are done, click on `Run` > `Restart Kernel and Run All Cells...` and verify the output.
# - Q: Plot `total_bill` using an appropriate plot. Is the distribution left- or right-skewed?
# - A: Left Skewed
# - Q: Plot `sex` (which indicates the gender of the bill payer) using an appropriate plot. Are there more female or male bill payers?
# - A: There are more Male bill payers
# - Q: Plot `time` and `total_bill` using an appropriate plot. Is the bill typically higher at lunch or dinner?
# - A: Dinner has higher bill
# - Q: Plot `day` and `time` using an appropriate plot. On which day did most lunches occur?
# - A: most lunches occured on thursday
# - Q: Plot `total_bill` and `tip_rate` using an appropriate plot. Does the tip rate appear to be higher for lower bills? Or does the tip rate appear to be higher for higher bills?
# - A: the tip rate is higher for lower bills

# %%
import pandas as pd
import seaborn as sns

# %%
TIPS= pd.read_csv('tips.csv')

# %%
TIPS
# Out:
#      total_bill   tip  tip_rate     sex smoker   day    time  size
# 0         16.99  1.01      5.94  Female     No   Sun  Dinner     2
# 1         10.34  1.66     16.05    Male     No   Sun  Dinner     3
# 2         21.01  3.50     16.66    Male     No   Sun  Dinner     3
# 3         23.68  3.31     13.98    Male     No   Sun  Dinner     2
# 4         24.59  3.61     14.68  Female     No   Sun  Dinner     4
# ..          ...   ...       ...     ...    ...   ...     ...   ...
# 239       29.03  5.92     20.39    Male     No   Sat  Dinner     3
# 240       27.18  2.00      7.36  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00      8.82    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75      9.82    Male     No   Sat  Dinner     2
# 243       18.78  3.00     15.97  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
sns.histplot(data=TIPS, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.countplot(data=TIPS, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(data=TIPS, x='time', y='total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.countplot(data=TIPS, x='day',hue='time')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.scatterplot(data=TIPS, x='tip_rate',y='total_bill')
# Out:
# <Axes: xlabel='tip_rate', ylabel='total_bill'>

# %% [markdown]
# Answer the following questions about `avocados.csv`, which contains data about the average price of a single avocado courtesy of the Hass Avocado Board. Include your final code below. When you are done, click on `Run` > `Restart Kernel and Run All Cells...` and verify the output.
# - Q: Plot the variables in the dataset. When, approximately, was the average avocado price the lowest/highest?
# - A: Lowest was approximately between 2017-01 and 2017-07
# -    Highest was approximately between 2017-08 and 2017-09

# %%
AV= pd.read_csv('avocados.csv')

# %%
AV
# Out:
#      AveragePrice  TradingDay
# 0            0.90  2015-12-27
# 1            0.94  2015-12-20
# 2            0.87  2015-12-13
# 3            0.78  2015-12-06
# 4            0.91  2015-11-29
# ..            ...         ...
# 164          0.80  2018-02-04
# 165          1.16  2018-01-28
# 166          1.12  2018-01-21
# 167          1.27  2018-01-14
# 168          1.19  2018-01-07
#
# [169 rows x 2 columns]

# %%
AV['TradingDay']=pd.to_datetime(AV['TradingDay'])

# %%
sns.lineplot(data=AV, x='TradingDay', y='AveragePrice').tick_params(labelrotation=45)
