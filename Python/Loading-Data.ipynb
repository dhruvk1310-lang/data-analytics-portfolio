# %% [markdown]
# # Exercise: Loading Data

# %% [markdown]
# Please load each of the 4 files containing data about numerous businesses on Yelp and answer the following questions. Include your final code below. When you are done, click on `Run` > `Restart Kernel and Run All Cells...` and verify the output.
# - Q: How many rows does `yelp1.csv` contain?
# - A: 627
# - Q: What is the data type of `name`?
# - A: Object
# - Q: How many rows does `yelp2.csv` contain?
# - A: 600
# - Q: What is the data type of `take_out`?
# - A: bool
# - Q: How many rows does `yelp3.csv` contain?
# - A: 629
# - Q: What is the data type of `review_count`?
# - A: Integer
# - Q: How many rows does `yelp4.csv` contain?
# - A: 638
# - Q: What is the data type of `stars`?
# - A: Float

# %% [markdown]
# ## Importing data as "pandas"

# %%
import pandas as pd

# %%
Y1=pd.read_csv('yelp1.csv', sep='\t')

# %%
Y1
# Out:
#                                        name   main_category  \
# 0                               Dairy Queen            Food
# 1                   Dan Cercone Hairstyling         Barbers
# 2    Decio's Custom Tailoring & Formal Wear  Local Services
# 3               Dependable Brakes & Exhaust     Auto Repair
# 4                               Doc's Place            Bars
# ..                                      ...             ...
# 622                Galaxy Foam & Upholstery  Local Services
# 623                     Pilot Travel Center      Automotive
# 624                        Bonita Groceries            Food
# 625                 La Bonita Grocery Store            Food
# 626                        Morris Dexter OD    Optometrists
#
#                   sub_category  take_out  review_count  stars
# 0    Ice Cream & Frozen Yogurt      True            10    3.5
# 1                Beauty & Spas     False            32    4.5
# ...

# %%
Y1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           627 non-null    object
#  1   main_category  627 non-null    object
#  2   sub_category   627 non-null    object
#  3   take_out       627 non-null    bool
#  4   review_count   627 non-null    int64
#  5   stars          627 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 25.2+ KB

# %%
Y2=pd.read_csv('yelp2.csv')

# %%
Y2
# Out:
#                                                   name   main_category  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                         sub_category  take_out  review_count  stars
# ...

# %%
Y2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           600 non-null    object
#  1   main_category  600 non-null    object
#  2   sub_category   600 non-null    object
#  3   take_out       600 non-null    bool
#  4   review_count   600 non-null    int64
#  5   stars          600 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 24.2+ KB

# %%
Y3=pd.read_csv('yelp3.csv',names=['name','main_category','sub_Category','take_Out','review_count','Star'])

# %%
Y3
# Out:
#                                     name   main_category  \
# 0                    Miller Ace Hardware        Shopping
# 1        Minutello's Restaurant & Lounge         Italian
# 2          Monro Muffler Brake & Service           Tires
# 3                          Moonlite Cafe     Restaurants
# 4                Morton's The Steakhouse     Restaurants
# ..                                   ...             ...
# 625  Habib's Tailoring & Leather Repairs  Local Services
# 626                        The UPS Store  Local Services
# 627                          China China        Shopping
# 628                            Cigar Box        Shopping
# 629                      Fabric Boutique        Shopping
#
#                sub_Category  take_Out  review_count  Star
# 0           Hardware Stores     False             5   4.5
# 1                     Pizza      True             8   3.0
# 2                Automotive     False             9   2.0
# ...

# %%
Y3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Miller Ace Hardware  629 non-null    object
#  1   Shopping             629 non-null    object
#  2   Hardware Stores      629 non-null    object
#  3   FALSE                629 non-null    bool
#  4   5                    629 non-null    int64
#  5   4.5                  629 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 25.3+ KB

# %%
Y4=pd.read_csv('yelp4.csv', sep=';')

# %%
Y4
# Out:
#                              name         main_category  \
# 0           Eat'n Park Restaurant             Fast Food
# 1               Econowash Laundry        Local Services
# 2              Eddie's Pizza Haus               Italian
# 3           Elite Coach Limousine       Hotels & Travel
# 4                      Elks B P O  Arts & Entertainment
# ..                            ...                   ...
# 633  Morton's Valero Travel Plaza                 Tires
# 634              Cool Cuts 4 Kids         Beauty & Spas
# 635                   Great Clips         Beauty & Spas
# 636  Silver Nugget Bowling Center           Active Life
# 637                  Poker Palace  Arts & Entertainment
#
#                sub_category  take_out  review_count  stars
# 0    American (Traditional)      True            21    3.5
# 1    Dry Cleaning & Laundry     False             6    2.0
# 2                     Pizza      True             8    4.0
# ...

# %%
Y4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           638 non-null    object
#  1   main_category  638 non-null    object
#  2   sub_category   638 non-null    object
#  3   take_out       638 non-null    bool
#  4   review_count   638 non-null    int64
#  5   stars          638 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 25.7+ KB
