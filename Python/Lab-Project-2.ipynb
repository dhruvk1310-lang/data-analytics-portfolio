# %% [markdown]
# # Dhruva Khanna

# %% [markdown]
# # Lab Project 2: Heart Disease

# %% [markdown]
# Please combine `healthinfo_characteristics1.csv`, `healthinfo_characteristics2.csv` and `healthinfo_heartdisease.csv` into one dataset. Hint: You'll have to use concatenate and merge. **Delete rows with missing data.** The files contain health-related demographic characteristics and heart disease for over 280k people from an American health survey. Specifically, the files include the following variables:
# - `id`: Unique identifier
# - `bmi`: BMI
# - `gener`: Gender
# - `ethnicity`: Ethnic Group
# - `age`: Age group
# - `smoking`: Whether or not smoking
# - `physicalactivity`:  Whether or not doing physical activity
# - `alcoholdrinkingheavy`: Whether or not drinking alcohol heavily
# - `heartdisease`: Whether or not having heart disease
#
# Please analyze the data and come up with **3 insights** that make use of the following:
# - **Descriptive statistics**
# - **Count of unique values**
# - **Groupby functions**
# - **At least 2 plots**
#
# Answer the following questions and include your final code below. When you are done, click on `Run` > `Restart Kernel and Run All Cells...` and verify the output.
# - Q: How many variables and rows are in the final dataset?
# - A: 319795 row
#
# - Q: What is your 1st insight? (Answer in 1-3 sentences.)
# -A: **High Engagement in Physical Activity**: The majority of individuals (77%) report being physically active, with only around 23% not engaging in physical activity.
#
#   **Physical Activity Visualization**: The bar plot confirms that most of the population is physically active, which might correlate with other health outcomes such as BMI and heart disease.
#
# - Q: What is your 2nd insight? (Answer in 1-3 sentences.)
# - A: **Low Prevalence of Heavy Drinking**: Only 6.8% of the population are heavy drinkers, while the remaining 93.2% do not engage in heavy alcohol drinking.
#
# - Q: What is your 3rd insight? (Answer in 1-3 sentences.)
# - A: **BMI Increases with Age**: Older age groups, especially those 65 and above, tend to have higher BMI values, with several individuals in this group showing BMI levels above 40.
#
# **Wide BMI Variability in Middle Age**: Individuals aged 40-60 show a wide range of BMI values, with many within the 20-40 BMI range, but some also showing outliers.

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('healthinfo_characteristics1.csv')

# %%
df
# Out:
#             id    bmi  gender ethnicity          age smoking physicalactivity  \
# 0       106599  34.75  Female     White        30-34     Yes              Yes
# 1       106600  25.80    Male     White        70-74     Yes              Yes
# 2       106601    NaN  Female     White        65-69     Yes              Yes
# 3       106602  24.28     NaN     White        70-74     Yes              Yes
# 4       106603  24.03  Female     White        65-69     Yes              Yes
# ...        ...    ...     ...       ...          ...     ...              ...
# 213192  319791  27.41    Male  Hispanic        60-64     Yes               No
# 213193  319792  29.84    Male  Hispanic        35-39     Yes              Yes
# 213194  319793  24.24  Female       NaN        45-49      No              Yes
# 213195  319794  32.81  Female  Hispanic        25-29      No               No
# 213196  319795  46.56  Female  Hispanic  80 or older      No              Yes
#
#        alcoholdrinkingheavy
# ...

# %%
df2=pd.read_csv('healthinfo_characteristics2.csv')

# %%
df2
# Out:
#             id    BMI  gender ethnicity          AGE smoking physicalactivity  \
# 0            1  16.60  Female     White        55-59     Yes              Yes
# 1            2  20.34  Female     White  80 or older      No              Yes
# 2            3  26.58    Male     White        65-69     Yes              Yes
# 3            4  24.21  Female     White        75-79      No               No
# 4            5  23.71  Female     White        40-44      No              Yes
# ...        ...    ...     ...       ...          ...     ...              ...
# 106593  106594  36.58    Male     White  80 or older     Yes               No
# 106594  106595  26.29  Female     White        70-74     Yes              Yes
# 106595  106596  26.54    Male     White        50-54     Yes              Yes
# 106596  106597  25.11    Male     White        75-79      No              Yes
# 106597  106598  29.12  Female     White        70-74      No              Yes
#
#        alcoholdrinkingheavy
# ...

# %%
df3=pd.read_csv('healthinfo_heartdisease.csv')

# %%
df3
# Out:
#             ID heartdisease
# 0            1           No
# 1            2           No
# 2            3           No
# 3            4           No
# 4            5           No
# ...        ...          ...
# 319790  319791          Yes
# 319791  319792           No
# 319792  319793           No
# 319793  319794           No
# 319794  319795           No
#
# [319795 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213197 entries, 0 to 213196
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    213197 non-null  int64
#  1   bmi                   204211 non-null  float64
#  2   gender                203662 non-null  object
#  3   ethnicity             208249 non-null  object
#  4   age                   213197 non-null  object
#  5   smoking               213197 non-null  object
#  6   physicalactivity      213197 non-null  object
#  7   alcoholdrinkingheavy  213197 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 13.0+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106598 entries, 0 to 106597
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    106598 non-null  int64
#  1   BMI                   104014 non-null  float64
#  2   gender                103884 non-null  object
#  3   ethnicity             101699 non-null  object
#  4   AGE                   106598 non-null  object
#  5   smoking               106598 non-null  object
#  6   physicalactivity      106598 non-null  object
#  7   alcoholdrinkingheavy  106598 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.5+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            319795 non-null  int64
#  1   heartdisease  303805 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 4.9+ MB

# %%
df2=df2.rename(columns={'BMI':'bmi','AGE':'age'})

# %%
df3=df3.rename(columns={'ID':'id'})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106598 entries, 0 to 106597
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    106598 non-null  int64
#  1   bmi                   104014 non-null  float64
#  2   gender                103884 non-null  object
#  3   ethnicity             101699 non-null  object
#  4   age                   106598 non-null  object
#  5   smoking               106598 non-null  object
#  6   physicalactivity      106598 non-null  object
#  7   alcoholdrinkingheavy  106598 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.5+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            319795 non-null  int64
#  1   heartdisease  303805 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 4.9+ MB

# %%
concat=pd.concat([df,df2])

# %%
concat
# Out:
#             id    bmi  gender ethnicity          age smoking physicalactivity  \
# 0       106599  34.75  Female     White        30-34     Yes              Yes
# 1       106600  25.80    Male     White        70-74     Yes              Yes
# 2       106601    NaN  Female     White        65-69     Yes              Yes
# 3       106602  24.28     NaN     White        70-74     Yes              Yes
# 4       106603  24.03  Female     White        65-69     Yes              Yes
# ...        ...    ...     ...       ...          ...     ...              ...
# 106593  106594  36.58    Male     White  80 or older     Yes               No
# 106594  106595  26.29  Female     White        70-74     Yes              Yes
# 106595  106596  26.54    Male     White        50-54     Yes              Yes
# 106596  106597  25.11    Male     White        75-79      No              Yes
# 106597  106598  29.12  Female     White        70-74      No              Yes
#
#        alcoholdrinkingheavy
# ...

# %%
concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 319795 entries, 0 to 106597
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    319795 non-null  int64
#  1   bmi                   308225 non-null  float64
#  2   gender                307546 non-null  object
#  3   ethnicity             309948 non-null  object
#  4   age                   319795 non-null  object
#  5   smoking               319795 non-null  object
#  6   physicalactivity      319795 non-null  object
#  7   alcoholdrinkingheavy  319795 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 22.0+ MB

# %%
df_inner=pd.merge(df3,concat, how='inner', on='id')

# %%
df_inner
# Out:
#             id heartdisease    bmi  gender ethnicity          age smoking  \
# 0            1           No  16.60  Female     White        55-59     Yes
# 1            2           No  20.34  Female     White  80 or older      No
# 2            3           No  26.58    Male     White        65-69     Yes
# 3            4           No  24.21  Female     White        75-79      No
# 4            5           No  23.71  Female     White        40-44      No
# ...        ...          ...    ...     ...       ...          ...     ...
# 319790  319791          Yes  27.41    Male  Hispanic        60-64     Yes
# 319791  319792           No  29.84    Male  Hispanic        35-39     Yes
# 319792  319793           No  24.24  Female       NaN        45-49      No
# 319793  319794           No  32.81  Female  Hispanic        25-29      No
# 319794  319795           No  46.56  Female  Hispanic  80 or older      No
#
#        physicalactivity alcoholdrinkingheavy
# ...

# %%
df_inner=df_inner.dropna()

# %%
df['physicalactivity'].value_counts()
# Out:
# physicalactivity
# Yes    165881
# No      47316
# Name: count, dtype: int64

# %%
df['alcoholdrinkingheavy'].value_counts()
# Out:
# alcoholdrinkingheavy
# No     198803
# Yes     14394
# Name: count, dtype: int64

# %%
df_inner.groupby(['gender','age'])['heartdisease'].value_counts(normalize=True)*100
# Out:
# gender  age          heartdisease
# Female  18-24        No              99.456051
#                      Yes              0.543949
#         25-29        No              99.118295
#                      Yes              0.881705
#         30-34        No              98.952812
#                      Yes              1.047188
#         35-39        No              98.611267
#                      Yes              1.388733
#         40-44        No              97.839736
#                      Yes              2.160264
#         45-49        No              97.236775
#                      Yes              2.763225
#         50-54        No              95.523042
#                      Yes              4.476958
#         55-59        No              94.448663
#                      Yes              5.551337
#         60-64        No              92.939452
#                      Yes              7.060548
#         65-69        No              92.044643
# ...

# %%
sns.histplot(data=df, x='physicalactivity')
# Out:
# <Axes: xlabel='physicalactivity', ylabel='Count'>

# %%
sns.scatterplot(data=df_inner, x='bmi', y='age')
# Out:
# <Axes: xlabel='bmi', ylabel='age'>
